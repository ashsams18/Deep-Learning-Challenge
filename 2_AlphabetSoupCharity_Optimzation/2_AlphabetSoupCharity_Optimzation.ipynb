# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME  ... ASK_AMT IS_SUCCESSFUL
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB  ...    5000             1
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR  ...  108590             1
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS  ...    5000             0
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION  ...    6692             1
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT  ...  142590             1
#
# [5 rows x 12 columns]

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
Drop_df = application_df.drop(columns =["EIN","NAME"])
Drop_df
# Out:
#       APPLICATION_TYPE       AFFILIATION  ...   ASK_AMT IS_SUCCESSFUL
# 0                  T10       Independent  ...      5000             1
# 1                   T3       Independent  ...    108590             1
# 2                   T5  CompanySponsored  ...      5000             0
# 3                   T3  CompanySponsored  ...      6692             1
# 4                   T3       Independent  ...    142590             1
# ...                ...               ...  ...       ...           ...
# 34294               T4       Independent  ...      5000             0
# 34295               T4  CompanySponsored  ...      5000             0
# 34296               T3  CompanySponsored  ...      5000             0
# 34297               T5       Independent  ...      5000             1
# 34298               T3       Independent  ...  36500179             0
#
# [34299 rows x 10 columns]

# %%
# Determine the number of unique values in each column.
Drop_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
Binned_df = Drop_df["APPLICATION_TYPE"].value_counts()
Binned_df
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T14        3
# T25        3
# T15        2
# T29        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = Binned_df[Binned_df <= 500]
application_types_to_replace = application_types_to_replace.index.values

# %%
#application_types_to_replace
for app in application_types_to_replace:
    Drop_df['APPLICATION_TYPE'] = Drop_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
Drop_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
Binned2_df = Drop_df["CLASSIFICATION"].value_counts()
Binned2_df
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C1732        1
# C2190        1
# C2380        1
# C4120        1
# C1580        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
Binned2_df[Binned2_df >1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C2300       32
# C7200       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1278       10
# C1238       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1600        5
# C1257        5
# C0           3
# C1260        3
# C2710        3
# C1234        2
# C1246        2
# C3200        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = Binned2_df[Binned2_df <= 1200]
classifications_to_replace = classifications_to_replace.index.values

# %%
# Replace in dataframe
for cls in classifications_to_replace:
    Drop_df['CLASSIFICATION'] = Drop_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
Drop_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
#  YOUR CODE GOES HERE

Dummies_df = pd.get_dummies(Drop_df)
Dummies_df
# Out:
#        STATUS   ASK_AMT  ...  SPECIAL_CONSIDERATIONS_N  SPECIAL_CONSIDERATIONS_Y
# 0           1      5000  ...                         1                         0
# 1           1    108590  ...                         1                         0
# 2           1      5000  ...                         1                         0
# 3           1      6692  ...                         1                         0
# 4           1    142590  ...                         1                         0
# ...       ...       ...  ...                       ...                       ...
# 34294       1      5000  ...                         1                         0
# 34295       1      5000  ...                         1                         0
# 34296       1      5000  ...                         1                         0
# 34297       1      5000  ...                         1                         0
# 34298       1  36500179  ...                         1                         0
#
# ...

# %%
# Split our preprocessed data into our features and target arrays
#  YOUR CODE GOES HERE
y = Dummies_df["IS_SUCCESSFUL"].values
X = Dummies_df.drop(["IS_SUCCESSFUL"],1).values
# Split the preprocessed data into a training and testing dataset
#  YOUR CODE GOES HERE

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=2, stratify=y)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=8, input_dim=len(X_train[0]), activation="relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=5, activation="relu"))

nn.add(tf.keras.layers.Dense(units=5, activation="relu"))

nn.add(tf.keras.layers.Dense(units=5, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_4 (Dense)             (None, 8)                 352
#
#  dense_5 (Dense)             (None, 5)                 45
#
#  dense_6 (Dense)             (None, 5)                 30
#
#  dense_7 (Dense)             (None, 5)                 30
#
#  dense_8 (Dense)             (None, 1)                 6
#
# ...
# Total params: 463
# Trainable params: 463
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=150)
# Out:
# Epoch 1/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6256 - accuracy: 0.6871
# Epoch 2/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5712 - accuracy: 0.7252
# Epoch 3/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5621 - accuracy: 0.7247
# Epoch 4/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5589 - accuracy: 0.7267
# Epoch 5/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5574 - accuracy: 0.7282
# Epoch 6/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5555 - accuracy: 0.7284
# Epoch 7/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5551 - accuracy: 0.7269
# Epoch 8/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5538 - accuracy: 0.7284
# Epoch 9/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5528 - accuracy: 0.7291
# Epoch 10/150
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5505 - accuracy: 0.7307 - 415ms/epoch - 2ms/step
# Loss: 0.5505258440971375, Accuracy: 0.7307288646697998

# %%
# Export our model to HDF5 file
#  YOUR CODE GOES HERE
nn.save("2nd_AlphabetSoupCharity_Optimization.h5")
